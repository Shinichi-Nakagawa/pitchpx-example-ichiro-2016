# %%
# %matplotlib inline

import pandas as pd


pd.options.display.max_columns = 100
pd.options.display.max_rows = 400

# %%
atbats = pd.read_csv('./output/datasets/atbat2015.csv')

# %%
ichiro_suzuki_atbats = atbats.query("bat_box_name=='Suzuki, I' and regseason_fl == 'T'")

# %%
ichiro_suzuki_atbats.to_csv('./output/datasets/ichiro_suzuki_2015_atbats.csv')

# %%
pitchfx = pd.read_csv('./output/datasets/pitch2015.csv')

# %%
ichiro_suzuki_pitchfx = pitchfx.query("bat_box_name=='Suzuki, I' and regseason_fl == 'T'")

# %%
ichiro_suzuki_pitchfx.to_csv('./output/datasets/ichiro_suzuki_2015_pitchfx.csv')

# %%
len(ichiro_suzuki_pitchfx.query('pa_event_cd in [20, 21, 22, 23]'))
# Out:
# 319

# %%
ichiro_suzuki_pitchfx
# Out:
#         Unnamed: 0 retro_game_id  year  month  day st_fl regseason_fl  \
# 11977          452  MIA201504060  2015      4    6     F            T
# 11978          453  MIA201504060  2015      4    6     F            T
# 11979          454  MIA201504060  2015      4    6     F            T
# 15735          483  MIA201504070  2015      4    7     F            T
# 15736          484  MIA201504070  2015      4    7     F            T
# 17762          486  MIA201504080  2015      4    8     F            T
# 17763          487  MIA201504080  2015      4    8     F            T
# 28217         4098  MIA201504100  2015      4   10     F            T
# 28218         4099  MIA201504100  2015      4   10     F            T
# 32334         3544  MIA201504110  2015      4   11     F            T
# 32335         3545  MIA201504110  2015      4   11     F            T
# 32336         3546  MIA201504110  2015      4   11     F            T
# ...
